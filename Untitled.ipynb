# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
import yfinance as yf
# Out:
# Using TensorFlow backend.

# %%
df = yf.download("AAPL", start="2016-01-01", end="2021-10-09")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2016-01-04  25.652500  26.342501  25.500000  26.337500  24.323219  270597600
# 2016-01-05  26.437500  26.462500  25.602501  25.677500  23.713696  223164000
# 2016-01-06  25.139999  25.592501  24.967501  25.174999  23.249626  273829600
# 2016-01-07  24.670000  25.032499  24.107500  24.112499  22.268383  324377600
# 2016-01-08  24.637501  24.777500  24.190001  24.240000  22.386133  283192000

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price ($)')
plt.show()

# %%
forecast_out = 30
df['Predictions'] = df['Adj Close'].shift(-forecast_out)
df = df[['Adj Close', 'Predictions']]
df.tail()
# Out:
#              Adj Close  Predictions
# Date
# 2021-07-02  139.960007          NaN
# 2021-07-06  142.020004          NaN
# 2021-07-07  144.570007          NaN
# 2021-07-08  143.240005          NaN
# 2021-07-09  145.110001          NaN

# %%
X = df.drop(['Predictions'], axis=1)
X = X[:-forecast_out]
X.tail()
# Out:
#              Adj Close
# Date
# 2021-05-20  127.309998
# 2021-05-21  125.430000
# 2021-05-24  127.099998
# 2021-05-25  126.900002
# 2021-05-26  126.849998

# %%
y = df['Predictions']
y = y[:-forecast_out]
y.tail()
# Out:
# Date
# 2021-05-20    139.960007
# 2021-05-21    142.020004
# 2021-05-24    144.570007
# 2021-05-25    143.240005
# 2021-05-26    145.110001
# Name: Predictions, dtype: float64

# %%
print(X.shape, y.shape)
# Out:
# (1359, 1) (1359,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
predicted = model.predict(X_test)
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 63.29436272927837
# R-squared (R2 ): 0.9460943892546496

# %%
predictions = model.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   [ 40.15467731 127.78007074  43.38696447  28.98866088  28.29858679
#   28.5997328   43.86236804  56.33649607  48.99401901  41.28402455]
# First 10 Actual labels: [37.10944747924805, 115.92890930175781, 42.307701110839844, 26.881210327148438, 28.314956665039062, 26.169559478759766, 45.59850311279297, 60.74015808105469, 50.96432876586914, 41.68442153930664]

# %%
pd.DataFrame({"Actual": y_test, "Prediction": predictions})
# Out:
#                 Actual  Prediction
# Date
# 2017-08-24   37.109447   40.154677
# 2020-08-21  115.928909  127.780071
# 2017-11-03   42.307701   43.386964
# 2016-09-15   26.881210   28.988661
# 2016-12-08   28.314957   28.298587
# ...                ...         ...
# 2020-05-07   86.844833   78.153693
# 2018-09-06   52.399181   56.573482
# 2016-10-28   26.740721   28.544508
# 2016-05-03   22.686680   23.832754
# 2020-01-02   80.475937   77.115231
#
# [340 rows x 2 columns]

# %%
df2 = yf.download("AMZN", start="2016-01-01", end="2021-10-09")
df2
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-01-04   656.289978   657.719971   627.510010   636.989990   636.989990
# 2016-01-05   646.859985   646.909973   627.650024   633.789978   633.789978
# 2016-01-06   622.000000   639.789978   620.309998   632.650024   632.650024
# 2016-01-07   621.799988   630.000000   605.210022   607.940002   607.940002
# 2016-01-08   619.659973   624.140015   606.000000   607.049988   607.049988
# ...                 ...          ...          ...          ...          ...
# 2021-07-02  3451.639893  3511.719971  3436.919922  3510.979980  3510.979980
# 2021-07-06  3530.110107  3685.479980  3529.000000  3675.739990  3675.739990
# 2021-07-07  3717.379883  3734.199951  3678.909912  3696.580078  3696.580078
# 2021-07-08  3643.560059  3759.989990  3621.120117  3731.409912  3731.409912
# 2021-07-09  3722.520020  3748.000000  3693.399902  3719.340088  3719.340088
#
#              Volume
# Date
# 2016-01-04  9314500
# 2016-01-05  5822600
# 2016-01-06  5329200
# 2016-01-07  7074900
# 2016-01-08  5512900
# ...             ...
# 2021-07-02  3169400
# 2021-07-06  6744800
# 2021-07-07  5328100
# 2021-07-08  5180600
# 2021-07-09  3745100
#
# [1389 rows x 6 columns]

# %%
forecast_out = 30
df2['Predictions'] = df2['Adj Close'].shift(-forecast_out)
df2 = df2[['Adj Close', 'Predictions']]
df2.tail()
# Out:
#               Adj Close  Predictions
# Date
# 2021-07-02  3510.979980          NaN
# 2021-07-06  3675.739990          NaN
# 2021-07-07  3696.580078          NaN
# 2021-07-08  3731.409912          NaN
# 2021-07-09  3719.340088          NaN

# %%
X2 = df2.drop(['Predictions'], axis=1)
X2 = X2[:-forecast_out]
X2.tail()
# Out:
#               Adj Close
# Date
# 2021-05-20  3247.679932
# 2021-05-21  3203.080078
# 2021-05-24  3244.989990
# 2021-05-25  3259.050049
# 2021-05-26  3265.159912

# %%
y2 = df2['Predictions']
y2 = y2[:-forecast_out]
y2.tail()
# Out:
# Date
# 2021-05-20    3510.979980
# 2021-05-21    3675.739990
# 2021-05-24    3696.580078
# 2021-05-25    3731.409912
# 2021-05-26    3719.340088
# Name: Predictions, dtype: float64

# %%
predictions = model.predict(X2)
pd.DataFrame({"Prediction": predictions, "Actual": y2})
# Out:
#              Prediction       Actual
# Date
# 2016-01-04   652.526614   534.099976
# 2016-01-05   649.254794   525.000000
# 2016-01-06   648.089260   534.900024
# 2016-01-07   622.824744   559.500000
# 2016-01-08   621.914757   552.940002
# ...                 ...          ...
# 2021-05-20  3321.800529  3510.979980
# 2021-05-21  3276.199853  3675.739990
# 2021-05-24  3319.050225  3696.580078
# 2021-05-25  3333.425792  3731.409912
# 2021-05-26  3339.672760  3719.340088
#
# [1359 rows x 2 columns]

# %%
df2 = yf.download("AMZN", start="2016-01-04", end="2016-02-05")
df2.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-29  571.979980  593.000000  570.000000  587.000000  587.000000
# 2016-02-01  578.150024  581.799988  570.309998  574.809998  574.809998
# 2016-02-02  570.000000  571.559998  550.090027  552.099976  552.099976
# 2016-02-03  553.500000  556.000000  521.900024  531.070007  531.070007
# 2016-02-04  525.000000  538.989990  519.219971  536.260010  536.260010
#
#               Volume
# Date
# 2016-01-29  14677600
# 2016-02-01   6355100
# 2016-02-02   6312000
# 2016-02-03  10048700
# 2016-02-04   6199100
